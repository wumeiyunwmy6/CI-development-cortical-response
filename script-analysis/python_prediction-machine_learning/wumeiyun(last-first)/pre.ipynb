# %%
import pandas as pd
data= pd.read_csv(r"E:\wumeiyun(last-first)\MachineLearningLast1_raw.csv")
data.head()
# Out:
#    sub_ID      DATE  times gender  age_implantation CI  CIU  NonCIU  HAtime  \
# 0       4  20171204   0.83   girl                42  R  100      90      12
# 1       4  20171227   1.60   girl                42  R  100      90      12
# 2       6  20171116   0.23   girl                36  R   98      76      12
# 3       6  20171204   0.83   girl                36  R   98      76      12
# 4       6  20171227   1.60   girl                36  R   98      76      12
#
#    ITMAIS  ...   bs_ch11   bs_ch12   bs_ch13   bs_ch14   bs_ch15   bs_ch16  \
# 0    62.5  ... -0.243482 -0.384136 -0.098961 -0.798351 -0.550401 -0.674056
# 1    77.5  ... -0.180343 -0.149472  0.139737  0.524460  0.370684  0.249931
# 2    32.5  ... -0.056891 -0.029921  0.489503 -0.478912  0.260515 -0.029921
# 3    47.5  ...  0.123072 -0.531874  0.162263 -0.243628 -0.002040  0.791686
# 4    55.0  ... -0.629934  0.072141 -0.295447  0.303808 -0.185798  0.404119
#
#     bs_ch17   bs_ch18   bs_ch19   bs_ch20
# ...

# %%
from collections import Counter
def get_count_by_counter(l):
    count = Counter(l)   #类型： <class 'collections.Counter'>
    count_dict = dict(count)   #类型： <type 'dict'>
    return count_dict
X_sub_ID_count_dict=get_count_by_counter(data["sub_ID"].values.tolist())
#字典中键值对的数量
num_sub=X_sub_ID_count_dict.__len__()
print(num_sub)
X_sub_ID_count_list=list(X_sub_ID_count_dict.items())
print(X_sub_ID_count_list)
# Out:
# 47
# [(4, 2), (6, 4), (7, 5), (8, 6), (11, 4), (12, 3), (13, 3), (16, 4), (17, 2), (18, 3), (20, 5), (21, 2), (22, 4), (23, 4), (24, 3), (25, 2), (28, 2), (32, 3), (38, 4), (44, 5), (45, 5), (50, 5), (56, 4), (57, 5), (58, 4), (63, 5), (78, 2), (79, 5), (80, 2), (86, 3), (89, 3), (91, 3), (96, 3), (103, 3), (104, 2), (105, 2), (110, 3), (112, 4), (114, 2), (115, 2), (116, 4), (125, 4), (126, 3), (127, 3), (128, 5), (129, 2), (135, 2)]

# %%
import pandas as pd

data_score=pd.read_csv(r"E:\wumeiyun(last-first)\MachineLearningLast1_change.csv") #运行前将表格数据清空
print(data_score)
index=0#整个数据表的行数
value_temp=0
for i in range(num_sub):
    #print("i:",i)
    key=X_sub_ID_count_list[i][0]   #被试编号
    value=X_sub_ID_count_list[i][1] #测试次数
    if value==1:
        first_index=index
        index=first_index+value
        continue
    first_index=index
    last_index=first_index+value-1
    index=first_index+value
    first_times = data["times"].values.tolist()[first_index]
    first_performance = data["performance"].values.tolist()[first_index]
    last_times=data["times"].values.tolist()[last_index]
    last_performance=data["performance"].values.tolist()[last_index]
    score=(last_performance*100-first_performance*100)/(last_times*100-first_times*100)
    times_change=last_times*100-first_times*100 #100倍的时间变化
    
    #babble
    b_ch1_change=(data["b_ch1"].values.tolist()[last_index]*100-data["b_ch1"].values.tolist()[first_index]*100)/times_change
    b_ch2_change=(data["b_ch2"].values.tolist()[last_index]*100-data["b_ch2"].values.tolist()[first_index]*100)/times_change
    b_ch3_change=(data["b_ch3"].values.tolist()[last_index]*100-data["b_ch3"].values.tolist()[first_index]*100)/times_change
    b_ch4_change=(data["b_ch4"].values.tolist()[last_index]*100-data["b_ch4"].values.tolist()[first_index]*100)/times_change
    b_ch5_change=(data["b_ch5"].values.tolist()[last_index]*100-data["b_ch5"].values.tolist()[first_index]*100)/times_change
    b_ch6_change=(data["b_ch6"].values.tolist()[last_index]*100-data["b_ch6"].values.tolist()[first_index]*100)/times_change
    b_ch7_change=(data["b_ch7"].values.tolist()[last_index]*100-data["b_ch7"].values.tolist()[first_index]*100)/times_change
    b_ch8_change=(data["b_ch8"].values.tolist()[last_index]*100-data["b_ch8"].values.tolist()[first_index]*100)/times_change
    b_ch9_change=(data["b_ch9"].values.tolist()[last_index]*100-data["b_ch9"].values.tolist()[first_index]*100)/times_change
    b_ch10_change=(data["b_ch10"].values.tolist()[last_index]*100-data["b_ch10"].values.tolist()[first_index]*100)/times_change
    b_ch11_change=(data["b_ch11"].values.tolist()[last_index]*100-data["b_ch11"].values.tolist()[first_index]*100)/times_change
    b_ch12_change=(data["b_ch12"].values.tolist()[last_index]*100-data["b_ch12"].values.tolist()[first_index]*100)/times_change
    b_ch13_change=(data["b_ch13"].values.tolist()[last_index]*100-data["b_ch13"].values.tolist()[first_index]*100)/times_change
    b_ch14_change=(data["b_ch14"].values.tolist()[last_index]*100-data["b_ch14"].values.tolist()[first_index]*100)/times_change
    b_ch15_change=(data["b_ch15"].values.tolist()[last_index]*100-data["b_ch15"].values.tolist()[first_index]*100)/times_change
    b_ch16_change=(data["b_ch16"].values.tolist()[last_index]*100-data["b_ch16"].values.tolist()[first_index]*100)/times_change
    b_ch17_change=(data["b_ch17"].values.tolist()[last_index]*100-data["b_ch17"].values.tolist()[first_index]*100)/times_change
    b_ch18_change=(data["b_ch18"].values.tolist()[last_index]*100-data["b_ch18"].values.tolist()[first_index]*100)/times_change
    b_ch19_change=(data["b_ch19"].values.tolist()[last_index]*100-data["b_ch19"].values.tolist()[first_index]*100)/times_change
    b_ch20_change=(data["b_ch20"].values.tolist()[last_index]*100-data["b_ch20"].values.tolist()[first_index]*100)/times_change
    
     
    #speech
    s_ch1_change=(data["s_ch1"].values.tolist()[last_index]*100-data["s_ch1"].values.tolist()[first_index]*100)/times_change
    s_ch2_change=(data["s_ch2"].values.tolist()[last_index]*100-data["s_ch2"].values.tolist()[first_index]*100)/times_change
    s_ch3_change=(data["s_ch3"].values.tolist()[last_index]*100-data["s_ch3"].values.tolist()[first_index]*100)/times_change
    s_ch4_change=(data["s_ch4"].values.tolist()[last_index]*100-data["s_ch4"].values.tolist()[first_index]*100)/times_change
    s_ch5_change=(data["s_ch5"].values.tolist()[last_index]*100-data["s_ch5"].values.tolist()[first_index]*100)/times_change
    s_ch6_change=(data["s_ch6"].values.tolist()[last_index]*100-data["s_ch6"].values.tolist()[first_index]*100)/times_change
    s_ch7_change=(data["s_ch7"].values.tolist()[last_index]*100-data["s_ch7"].values.tolist()[first_index]*100)/times_change
    s_ch8_change=(data["s_ch8"].values.tolist()[last_index]*100-data["s_ch8"].values.tolist()[first_index]*100)/times_change
    s_ch9_change=(data["s_ch9"].values.tolist()[last_index]*100-data["s_ch9"].values.tolist()[first_index]*100)/times_change
    s_ch10_change=(data["s_ch10"].values.tolist()[last_index]*100-data["s_ch10"].values.tolist()[first_index]*100)/times_change
    s_ch11_change=(data["s_ch11"].values.tolist()[last_index]*100-data["s_ch11"].values.tolist()[first_index]*100)/times_change
    s_ch12_change=(data["s_ch12"].values.tolist()[last_index]*100-data["s_ch12"].values.tolist()[first_index]*100)/times_change
    s_ch13_change=(data["s_ch13"].values.tolist()[last_index]*100-data["s_ch13"].values.tolist()[first_index]*100)/times_change
    s_ch14_change=(data["s_ch14"].values.tolist()[last_index]*100-data["s_ch14"].values.tolist()[first_index]*100)/times_change
    s_ch15_change=(data["s_ch15"].values.tolist()[last_index]*100-data["s_ch15"].values.tolist()[first_index]*100)/times_change
    s_ch16_change=(data["s_ch16"].values.tolist()[last_index]*100-data["s_ch16"].values.tolist()[first_index]*100)/times_change
    s_ch17_change=(data["s_ch17"].values.tolist()[last_index]*100-data["s_ch17"].values.tolist()[first_index]*100)/times_change
    s_ch18_change=(data["s_ch18"].values.tolist()[last_index]*100-data["s_ch18"].values.tolist()[first_index]*100)/times_change
    s_ch19_change=(data["s_ch19"].values.tolist()[last_index]*100-data["s_ch19"].values.tolist()[first_index]*100)/times_change
    s_ch20_change=(data["s_ch20"].values.tolist()[last_index]*100-data["s_ch20"].values.tolist()[first_index]*100)/times_change
    
  
    
    add_data_score=pd.Series({'sub_ID':data["sub_ID"].values.tolist()[first_index]
                              ,'times':data["times"].values.tolist()[first_index]
                              ,'gender':data["gender"].values.tolist()[first_index]
                              ,'age_implantation':data["age_implantation"].values.tolist()[first_index]
                              ,'CI':data["CI"].values.tolist()[first_index]
                              ,'HAtime':data["HAtime"].values.tolist()[first_index]
                              ,'CIU':data["CIU"].values.tolist()[first_index]
                              ,'NonCIU':data["NonCIU"].values.tolist()[first_index]
                              
                              #babble
                              ,'b_ch1_change':b_ch1_change
                              ,'b_ch2_change':b_ch2_change
                              ,'b_ch3_change':b_ch3_change
                              ,'b_ch4_change':b_ch4_change
                              ,'b_ch5_change':b_ch5_change
                              ,'b_ch6_change':b_ch6_change
                              ,'b_ch7_change':b_ch7_change
                              ,'b_ch8_change':b_ch8_change
                              ,'b_ch9_change':b_ch9_change
                              ,'b_ch10_change':b_ch10_change
                              ,'b_ch11_change':b_ch11_change
                              ,'b_ch12_change':b_ch12_change
                              ,'b_ch13_change':b_ch13_change
                              ,'b_ch14_change':b_ch14_change
                              ,'b_ch15_change':b_ch15_change
                              ,'b_ch16_change':b_ch16_change
                              ,'b_ch17_change':b_ch17_change
                              ,'b_ch18_change':b_ch18_change
                              ,'b_ch19_change':b_ch19_change
                              ,'b_ch20_change':b_ch20_change
                                                   
                              #speech
                              ,'s_ch1_change':s_ch1_change
                              ,'s_ch2_change':s_ch2_change
                              ,'s_ch3_change':s_ch3_change
                              ,'s_ch4_change':s_ch4_change
                              ,'s_ch5_change':s_ch5_change
                              ,'s_ch6_change':s_ch6_change
                              ,'s_ch7_change':s_ch7_change
                              ,'s_ch8_change':s_ch8_change
                              ,'s_ch9_change':s_ch9_change
                              ,'s_ch10_change':s_ch10_change
                              ,'s_ch11_change':s_ch11_change
                              ,'s_ch12_change':s_ch12_change
                              ,'s_ch13_change':s_ch13_change
                              ,'s_ch14_change':s_ch14_change
                              ,'s_ch15_change':s_ch15_change
                              ,'s_ch16_change':s_ch16_change
                              ,'s_ch17_change':s_ch17_change
                              ,'s_ch18_change':s_ch18_change
                              ,'s_ch19_change':s_ch19_change
                              ,'s_ch20_change':s_ch20_change   
                              
                               
                              #babble
                              ,'b_ch1':data["b_ch1"].values.tolist()[first_index]
                              ,'b_ch2':data["b_ch2"].values.tolist()[first_index]
                              ,'b_ch3':data["b_ch3"].values.tolist()[first_index]
                              ,'b_ch4':data["b_ch4"].values.tolist()[first_index]
                              ,'b_ch5':data["b_ch5"].values.tolist()[first_index]
                              ,'b_ch6':data["b_ch6"].values.tolist()[first_index]
                              ,'b_ch7':data["b_ch7"].values.tolist()[first_index]
                              ,'b_ch8':data["b_ch8"].values.tolist()[first_index]
                              ,'b_ch9':data["b_ch9"].values.tolist()[first_index]
                              ,'b_ch10':data["b_ch10"].values.tolist()[first_index]
                              ,'b_ch11':data["b_ch11"].values.tolist()[first_index]
                              ,'b_ch12':data["b_ch12"].values.tolist()[first_index]
                              ,'b_ch13':data["b_ch13"].values.tolist()[first_index]
                              ,'b_ch14':data["b_ch14"].values.tolist()[first_index]
                              ,'b_ch15':data["b_ch15"].values.tolist()[first_index]
                              ,'b_ch16':data["b_ch16"].values.tolist()[first_index]
                              ,'b_ch17':data["b_ch17"].values.tolist()[first_index]
                              ,'b_ch18':data["b_ch18"].values.tolist()[first_index]
                              ,'b_ch19':data["b_ch19"].values.tolist()[first_index]
                              ,'b_ch20':data["b_ch20"].values.tolist()[first_index]
                              
                              #speech
                              ,'s_ch1':data["s_ch1"].values.tolist()[first_index]
                              ,'s_ch2':data["s_ch2"].values.tolist()[first_index]
                              ,'s_ch3':data["s_ch3"].values.tolist()[first_index]
                              ,'s_ch4':data["s_ch4"].values.tolist()[first_index]
                              ,'s_ch5':data["s_ch5"].values.tolist()[first_index]
                              ,'s_ch6':data["s_ch6"].values.tolist()[first_index]
                              ,'s_ch7':data["s_ch7"].values.tolist()[first_index]
                              ,'s_ch8':data["s_ch8"].values.tolist()[first_index]
                              ,'s_ch9':data["s_ch9"].values.tolist()[first_index]
                              ,'s_ch10':data["s_ch10"].values.tolist()[first_index]
                              ,'s_ch11':data["s_ch11"].values.tolist()[first_index]
                              ,'s_ch12':data["s_ch12"].values.tolist()[first_index]
                              ,'s_ch13':data["s_ch13"].values.tolist()[first_index]
                              ,'s_ch14':data["s_ch14"].values.tolist()[first_index]
                              ,'s_ch15':data["s_ch15"].values.tolist()[first_index]
                              ,'s_ch16':data["s_ch16"].values.tolist()[first_index]
                              ,'s_ch17':data["s_ch17"].values.tolist()[first_index]
                              ,'s_ch18':data["s_ch18"].values.tolist()[first_index]
                              ,'s_ch19':data["s_ch19"].values.tolist()[first_index]
                              ,'s_ch20':data["s_ch20"].values.tolist()[first_index]
                              
                              ,'score':score
                              })
    data_score=data_score.append(add_data_score,ignore_index=True)

#print("data_score:",data_score)
print(data_score.head())
print("ok")
# Out:
# Empty DataFrame
# ...

# %%
data_score.to_csv('E:\\wumeiyun(last-first)\\MachineLearningLast1_change.csv')
print("ok")
# Out:
# ok
